# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import csv

# %%
df_house = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# # read data

# %%
df_house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# # display dataframe

# %%
df_house.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # this line checks for empty or missing data, this dataset is pretty clean with no missing values

# %%
df_house.shape
# Out:
# (21613, 21)

# %%
df_house = df_house[ (df_house['zipcode'] == 98039) ]

# %% [markdown]
# # select houses in a certain zip code

# %%
y = df_house['price'].values
x = df_house['sqft_living'].values

# %% [markdown]
# # get data of price and square feet

# %%
X = x.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2, random_state=100)

# %% [markdown]
# # here, we split the data into a training set and a testing set

# %%
plt.scatter(x, y)
plt.xlabel('footage')
plt.ylabel('price')
plt.title('house sale data')
plt.show()

# %% [markdown]
# # then we plot our data with a scatter

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_predict = model.predict(x_test)
print(f'train acc {round(model.score(x_train, y_train)*100,2)}%')
print(f'test acc {round(model.score(x_test, y_test)*100,2)}%')
# Out:
# train acc 86.74%
# test acc 93.21%

# %% [markdown]
# # the accuracy of our test and training models is pretty high

# %%
plt.scatter(x_train, y_train, color ='red')
plt.plot(x_test,y_predict)
plt.xlabel('footage')
plt.ylabel('price')
plt.title('house sale data')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %% [markdown]
# # oddly enough, as the square footage of a house increases so does it's price
